# %% [markdown]
# <a href="https://colab.research.google.com/github/Karan1928/Python-for-DS/blob/main/Forecasting_CocaCola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
sns.set()

# %%
rawdata = pd.read_csv('CocaCola_Sales_Rawdata.csv')
rawdata
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
year = []
month = []
for i in rawdata['Quarter']:
    year.append('19'+i[3:])
    if i[:2] == 'Q1':
        month.append('January')
    elif i[:2] == 'Q2':
        month.append('April')
    elif i[:2] == 'Q3':
        month.append('July')
    else:
        month.append('October')

data = rawdata.copy()
data['year'] = year
data['month'] = month
data['t'] = range(1, len(data)+1)
data['t_squared'] = data['t']**2
data
# Out:
#    Quarter        Sales  year    month   t  t_squared
# 0    Q1_86  1734.827000  1986  January   1          1
# 1    Q2_86  2244.960999  1986    April   2          4
# 2    Q3_86  2533.804993  1986     July   3          9
# 3    Q4_86  2154.962997  1986  October   4         16
# 4    Q1_87  1547.818996  1987  January   5         25
# 5    Q2_87  2104.411995  1987    April   6         36
# 6    Q3_87  2014.362999  1987     July   7         49
# 7    Q4_87  1991.746998  1987  October   8         64
# 8    Q1_88  1869.049999  1988  January   9         81
# 9    Q2_88  2313.631996  1988    April  10        100
# 10   Q3_88  2128.320000  1988     July  11        121
# 11   Q4_88  2026.828999  1988  October  12        144
# 12   Q1_89  1910.603996  1989  January  13        169
# 13   Q2_89  2331.164993  1989    April  14        196
# 14   Q3_89  2206.549995  1989     July  15        225
# 15   Q4_89  2173.967995  1989  October  16        256
# 16   Q1_90  2148.278000  1990  January  17        289
# 17   Q2_90  2739.307999  1990    April  18        324
# 18   Q3_90  2792.753998  1990     July  19        361
# 19   Q4_90  2556.009995  1990  October  20        400
# 20   Q1_91  2480.973999  1991  January  21        441
# 21   Q2_91  3039.522995  1991    April  22        484
# 22   Q3_91  3172.115997  1991     July  23        529
# 23   Q4_91  2879.000999  1991  October  24        576
# 24   Q1_92  2772.000000  1992  January  25        625
# 25   Q2_92  3550.000000  1992    April  26        676
# 26   Q3_92  3508.000000  1992     July  27        729
# 27   Q4_92  3243.859993  1992  October  28        784
# 28   Q1_93  3056.000000  1993  January  29        841
# 29   Q2_93  3899.000000  1993    April  30        900
# 30   Q3_93  3629.000000  1993     July  31        961
# 31   Q4_93  3373.000000  1993  October  32       1024
# 32   Q1_94  3352.000000  1994  January  33       1089
# 33   Q2_94  4342.000000  1994    April  34       1156
# 34   Q3_94  4461.000000  1994     July  35       1225
# 35   Q4_94  4017.000000  1994  October  36       1296
# 36   Q1_95  3854.000000  1995  January  37       1369
# 37   Q2_95  4936.000000  1995    April  38       1444
# 38   Q3_95  4895.000000  1995     July  39       1521
# 39   Q4_95  4333.000000  1995  October  40       1600
# 40   Q1_96  4194.000000  1996  January  41       1681
# 41   Q2_96  5253.000000  1996    April  42       1764

# %%
plt.plot(rawdata['Sales'])

# %%
sns.lineplot(x = 'year', y = 'Sales', data = data)

# %%
#Moving Average
plt.figure(figsize = (12,4))
data['Sales'].plot(label = 'Original')
for i in range(2,24,6):
    data['Sales'].rolling(i).mean().plot(label = 'Window size = ' + str(i))
plt.legend()

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(data['Sales'], lags = 4)
tsa_plots.plot_pacf(data['Sales'], lags = 4)
plt.show()

# %%
train = data['Sales'][:36]
test = data['Sales'][36:]
test
# Out:
# 36    3854.0
# 37    4936.0
# 38    4895.0
# 39    4333.0
# 40    4194.0
# 41    5253.0
# Name: Sales, dtype: float64

# %%
predictions = data['Sales'][37:]
test_val = data['Sales'][36:-1]
rmse = np.sqrt((mean_squared_error(test_val, predictions)))
rmse
# Out:
# 725.1277128892538

# %%
model = ARIMA(train, order=(3,1,0))
model_fit = model.fit()
forecast = model_fit.forecast(steps = 6)[0]
rmse = np.sqrt(np.mean((test - forecast)**2))
rmse
# Out:
# 429.10778869820894

# %%
model_fit.plot_predict(1, 79)

# %%
pred_df = pd.DataFrame()
pred_df['Actual'] = test
pred_df['Predictions'] = forecast
pred_df['% Error'] = abs(test - forecast) / test * 100
pred_df
# Out:
#     Actual  Predictions    % Error
# 36  3854.0  3709.511427   3.749055
# 37  4936.0  4342.512769  12.023647
# 38  4895.0  4669.202316   4.612823
# 39  4333.0  4370.811342   0.872637
# 40  4194.0  4056.216109   3.285262
# 41  5253.0  4440.412631  15.469015
