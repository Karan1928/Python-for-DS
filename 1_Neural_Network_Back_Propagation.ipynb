# %% [markdown]
# <a href="https://colab.research.google.com/github/Karan1928/Python-for-DS/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("/content/pima-indians-diabetes.data.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu'))
model.add(Dense(8,  activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 14s 23ms/step - loss: 4.1299 - accuracy: 0.5641 - val_loss: 2.9014 - val_accuracy: 0.5039
# Epoch 2/250
# 26/26 [==============================] - 0s 2ms/step - loss: 2.6394 - accuracy: 0.5077 - val_loss: 1.7316 - val_accuracy: 0.4882
# Epoch 3/250
# 26/26 [==============================] - 0s 3ms/step - loss: 1.8046 - accuracy: 0.5151 - val_loss: 1.2039 - val_accuracy: 0.6339
# Epoch 4/250
# 26/26 [==============================] - 0s 3ms/step - loss: 1.3097 - accuracy: 0.6103 - val_loss: 1.0461 - val_accuracy: 0.5551
# Epoch 5/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9988 - accuracy: 0.6075 - val_loss: 0.8850 - val_accuracy: 0.5748
# Epoch 6/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8720 - accuracy: 0.5969 - val_loss: 0.7402 - val_accuracy: 0.6496
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.7695
# accuracy: 76.95%
